# %% [markdown]
# # Normalized CSV preview

# %%
from pathlib import Path
import pandas as pd
csv_path = Path("/Users/mohamed/Desktop/Projects/NBA_Final/data/processed/data.csv")
df = pd.read_csv(csv_path)
df.head()
# Out:
#    HOME_GAME_ID  HOME_TEAM_ID  HOME_TEAM_ABBREVIATION  HOME_TEAM_CITY  \
# 0      21900001    1610612740                      17              17
# 1      21900002    1610612746                      11              11
# 2      21900003    1610612741                       3               3
# 3      21900004    1610612754                      10              10
# 4      21900005    1610612739                       4               4
#
#    HOME_MIN_TEAM  HOME_FGM_TEAM  HOME_FGA_TEAM  HOME_FG3M_TEAM  \
# 0          265.0             43            102              19
# 1          240.0             42             81              11
# 2          240.0             49            105               9
# 3          240.0             41             89               8
# 4          240.0             33             88               9
#
#    HOME_FG3A_TEAM  HOME_FTM_TEAM  ...  DIFF_TS_PCT  DIFF_EFG_PCT  DIFF_FGA  \
# 0              45             17  ...     0.007608      0.038978        -1
# ...

# %%
len(df)
# Out:
# 7050

# %%
for col in df.columns:
    print(col)
# Out:
# HOME_GAME_ID
# HOME_TEAM_ID
# HOME_TEAM_ABBREVIATION
# HOME_TEAM_CITY
# HOME_MIN_TEAM
# HOME_FGM_TEAM
# HOME_FGA_TEAM
# HOME_FG3M_TEAM
# HOME_FG3A_TEAM
# HOME_FTM_TEAM
# HOME_FTA_TEAM
# HOME_OREB_TEAM
# HOME_DREB_TEAM
# HOME_REB_TEAM
# HOME_AST_TEAM
# HOME_STL_TEAM
# HOME_BLK_TEAM
# HOME_TO_TEAM
# HOME_PF
# HOME_PTS_TEAM
# HOME_PLUS_MINUS_TEAM
# HOME_SEASON_ID
# HOME_GAME_DATE
# HOME_PTS_PLYR
# HOME_REB_PLYR
# HOME_AST_PLYR
# HOME_STL_PLYR
# HOME_BLK_PLYR
# HOME_TO_PLYR
# HOME_FGA_PLYR
# HOME_FGM_PLYR
# HOME_FG3A_PLYR
# HOME_FG3M_PLYR
# HOME_FTA_PLYR
# HOME_FTM_PLYR
# HOME_OREB_PLYR
# HOME_DREB_PLYR
# HOME_PLUS_MINUS_PLYR
# HOME_MIN_PLYR
# HOME_TS_PCT
# HOME_EFG_PCT
# HOME_FTR
# HOME_THREEPAR
# HOME_TEAM_ORDER
# AWAY_TEAM_ID
# AWAY_TEAM_ABBREVIATION
# AWAY_TEAM_CITY
# AWAY_MIN_TEAM
# AWAY_FGM_TEAM
# AWAY_FGA_TEAM
# AWAY_FG3M_TEAM
# AWAY_FG3A_TEAM
# AWAY_FTM_TEAM
# AWAY_FTA_TEAM
# AWAY_OREB_TEAM
# AWAY_DREB_TEAM
# AWAY_REB_TEAM
# AWAY_AST_TEAM
# AWAY_STL_TEAM
# AWAY_BLK_TEAM
# ...
